# %%
import pymysql
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# Read the dataset into a dataframe
df = pd.read_csv('.\\ny_data.csv')

# %%
df.head()
# Out:
#       CAMIS               DBA       BORO BUILDING            STREET  ZIPCODE  \
# 0  50045746       SILVER RICE   Brooklyn     575A   FLATBUSH AVENUE  11225.0
# 1  41269825    EL QUINTO PINO  Manhattan      401  WEST   24 STREET  10011.0
# 2  50087061  EARNEST TEA CAFE   Brooklyn     6008          8 AVENUE  11220.0
# 3  50037410          WINGSTOP  Manhattan       63  WEST  125 STREET  10027.0
# 4  41449659           POPEYES   Brooklyn     4930     KINGS HIGHWAY  11234.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  3477899874            Japanese       1/25/2019
# 1  2122066900      Latin American      10/26/2018
# 2  3474575888          Coffee/Tea       12/9/2019
# 3  2129879464             Chicken       12/9/2019
# 4  7184844754             Chicken       12/4/2017
#
#                                               ACTION  ... RECORD DATE  \
# 0    Violations were cited in the following area(s).  ...    3/6/2022
# ...

# %% [markdown]
# Let's check if there are any duplicate records.

# %% [markdown]
# Some attribute names need to be modified.

# %% [markdown]
# ***

# %%
df[df.duplicated()==True]
# Out:
#            CAMIS                                         DBA       BORO  \
# 19      41395881                                 THE VIG BAR  Manhattan
# 30      41580023                                        SAGE   Brooklyn
# 43      50043998                   THE STATION CRAFT CUISINE     Queens
# 44      50043998                   THE STATION CRAFT CUISINE     Queens
# 50      50011610                           BIG DADDY'S PIZZA   Brooklyn
# ...          ...                                         ...        ...
# 341465  41206524                               CHOICE MARKET   Brooklyn
# 341493  50054846                                        EONS     Queens
# 341494  50054846                                        EONS     Queens
# 341570  50059901  NEW YORK STOCK EXCHANGE EXECUTIVE SERVICES  Manhattan
# 341620  50085357                            MEMO SHISH KEBAB  Manhattan
#
#        BUILDING            STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# ...

# %%
df = df.drop_duplicates()

# %%
restaurant = df[['CAMIS', 'DBA', 'BUILDING', 'STREET', 'BORO', 'ZIPCODE', 'PHONE', 'CUISINE DESCRIPTION']]

# %%
print(restaurant)
# Out:
#            CAMIS                         DBA BUILDING                STREET  \
# 0       50045746                 SILVER RICE     575A       FLATBUSH AVENUE
# 1       41269825              EL QUINTO PINO      401      WEST   24 STREET
# 2       50087061            EARNEST TEA CAFE     6008              8 AVENUE
# 3       50037410                    WINGSTOP       63      WEST  125 STREET
# 4       41449659                     POPEYES     4930         KINGS HIGHWAY
# ...          ...                         ...      ...                   ...
# 341621  41477814  2 BROS PIZZA, CORVO COFFEE      542              9 AVENUE
# 341622  50001948              BLOOM'S TAVERN      208      EAST   58 STREET
# 341623  41290515    MI BELLA DAMA RESTAURANT      296  KNICKERBOCKER AVENUE
# 341624  41377321        DEILINE'S RESTAURANT     1544      EAST  174 STREET
# 341625  50041455                      DUNKIN      322     LIVINGSTON STREET
#
# ...
